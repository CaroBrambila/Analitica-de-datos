# %% [markdown]
# <a href="https://colab.research.google.com/github/CaroBrambila/Analitica-de-datos/blob/main/HolaMundo06_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##definimos dos arreglos
import numpy as np
import matplotlib.pyplot as plt

ys = 200 + np.random.rand(100)
xs = np.arange(0, 100, 1)

#graficas los arreglos en segundo plano
plt.plot(xs, ys, '*')
plt.fill_between(xs, ys, 200, facecolor='red', alpha=0.6)

plt.title("Simple visualización")
plt.xlabel("x",size=16)
plt.ylabel("y",size=16)
plt.show()

# %% [markdown]
# pandas:arreoglas los arreglos
# :operacines matematicasreria
# :graficar
# *comillas de la grafica
#
#
#  *plt es referrirnos a la lib
